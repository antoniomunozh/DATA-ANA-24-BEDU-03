# %%
from utils_distribuciones import generar_distribucion
import numpy as np

# %%
mu = 0
sigma = 1
dist_normal = np.random.normal(mu,sigma,1000)

# %%
# Uso de nuestra funcion generica
generar_distribucion(dist_normal, 'Distribución normal')
# Out:
# Distribución normal: asimetria -0.04, Curtosis: 0.27

# %% [markdown]
# # Distribución sesgada a la derecha

# %%
dist_sesgada = np.random.exponential(1,1000)
generar_distribucion(dist_sesgada, 'Distribución sesgada a la derecha')
# Out:
# Distribución sesgada a la derecha: asimetria 1.79, Curtosis: 4.44

# %% [markdown]
# # Distribucióin sesgada a la izquierda

# %%
dist_sesgada_izquierda = -np.random.exponential(1,1000)
generar_distribucion(dist_sesgada_izquierda, 'Distribución sesgada a la izquierda')
# Out:
# Distribución sesgada a la izquierda: asimetria -2.60, Curtosis: 12.36

# %% [markdown]
# # Distribución Bimodal

# %%
dist_bimodal = np.concatenate(
    [np.random.normal(mu,sigma,1000),
    np.random.normal(mu,sigma,1000)]
)
generar_distribucion(dist_bimodal, 'Distribución bimodal')
# Out:
# Distribución bimodal: asimetria 0.01, Curtosis: -0.14

# %% [markdown]
# # Distribución uniforme

# %%
dist_uniforme = np.random.uniform(-1, 1, 1000)

# Uso de nuestra funcion generica
generar_distribucion(dist_uniforme, 'Distribucion Uniforme')
# Out:
# Distribucion Uniforme: asimetria -0.05, Curtosis: -1.16
